# %% [markdown]
# <a href="https://colab.research.google.com/github/psmidhunreddy/fmml_projects_and_lab/blob/main/Module_1_Lab_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad
# # Module 1
# ## Lab 1: Basics of Python
# ### Module Coordinator:  Amit Pandey
#
# In this lab, we will be study basics of python

# %% [markdown]
# #### Question 0:
# ###### write down 3-5 methods applicable to each data type. (Hint: extend, reverse, etc.)

# %%
#String
s="heLLo WorLD"
print(s.capitalize()) # Capitalizes the string
print(s.lower()) # Converts all characters into lower case
print(s.upper()) # Converts all characters into upper case
print(s.swapcase()) # Converts lower case characters upper case and vice versa
print(s.title()) # Capitalizes each word in String
# Out:
# Hello world
# hello world
# HELLO WORLD
# HEllO wORld
# Hello World

# %%
#list
name_list = ['First Lab', 3 , '1.1' , 'Lab 1']
name_list.append("IIIt Hyd")
print("After first append",name_list)
n=len(name_list)
print("Length of list is :",n)
print("poped element ",name_list.pop())
name_list.remove(3)
print("After removing 3",name_list)
# Out:
# After first append ['First Lab', 3, '1.1', 'Lab 1', 'IIIt Hyd']
# Length of list is : 5
# poped element  IIIt Hyd
# After removing 3 ['First Lab', '1.1', 'Lab 1']

# %%
# Tuples

Tuple1 = (0, 1, 2, 3, 2, 3, 1, 3, 2)
res = Tuple1.count(3)
print('Count of 3 in Tuple1 is:', res)
res = Tuple1.index(3)
print('First occurrence of 3 is', res)
n=max(Tuple1)
print('Maximum of Tuple is', res)
# Out:
# Count of 3 in Tuple1 is: 3
# First occurrence of 3 is 3
# Maximum of Tuple is 3

# %%
#Sets
s = {'m', 'k', 'd', 'i'}

s.add('r')
print('Set after updating:', s)


s.discard('d')
print('Set after updating:', s)

s.remove('i')
print('Set after updating:', s)


print('Popped element', s.pop())
print('Set after updating:', s)

s.clear()
print('Set after updating:', s)
# Out:
# Set after updating: {'k', 'm', 'r', 'i', 'd'}
# Set after updating: {'k', 'm', 'r', 'i'}
# Set after updating: {'k', 'm', 'r'}
# Popped element k
# Set after updating: {'m', 'r'}
# Set after updating: set()

# %% [markdown]
# #### Question 1 :
#
# ##### Define a function, which takes in two strings A and B. Reverses the first string A, adds it to B, and returns the final string.

# %%
def RevStr(A: str, B: str):
    return A[::-1] + B

s=RevStr('Hello','Mello')
print(s)
# Out:
# olleHMello

# %% [markdown]
# #### Question 2 :
# ##### Given a list having Names, work_hours, and gender, Write a function to print name of the female worker that worked the most hours. Also how much do should she be paid if the pay is $ 20 per hour.
#
# ##### work_hours = [('Abby',100 , 'F'),('Billy',400, 'M'),('Cassie',800,'F'), ('Maggi',600,'F'),('Alex',500,'M'),('Raj',225,'M'),('Penny',920,'F'),('Ben',300,'M')]
#
# ##### Answer : the female worker that worked the most hours is Penny and she should be paid 18400

# %%
work_hours = [('Abby',100 , 'F'),('Billy',400, 'M'),('Cassie',800,'F'), ('Maggi',600,'F'),('Alex',500,'M'),('Raj',225,'M'),('Penny',920,'F'),('Ben',300,'M')]
female_hours = [(name, hours) for name, hours, gender in work_hours if gender == 'F']
max_hours = max(female_hours, key=lambda x: x[1])
print('Name:',max_hours[0],'\nPaid Amount:', max_hours[1] * 20)
# Out:
# Name: Penny
# Paid Amount: 18400

# %% [markdown]
# #### Question 3 :
# ##### Upload an image to your google drive, Use plt.imread to read image from the google drive and then print that image using plt.imshow

# %%
from matplotlib import pyplot as plt

# Read the image from Google Drive using plt.imread()
image = plt.imread('/content/drive/MyDrive/Colab Notebooks/OIP.jpeg')

# Display the image using plt.imshow()
plt.imshow(image)
plt.show()
